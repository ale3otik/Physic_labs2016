# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
% matplotlib inline
OX = np.arange(0,8,1)
m = []
m.append(1042.3)
d = []
d.append([0 ,127.3 ,255.7, 383.7 , 512.3 , 644.2, 775.3, 904.7])
print(m[0])
print(d[0])
plt.grid(True)
plt.plot(OX,d[0] , "-ob")
plt.show()
# Out:
# 1042.3
# [0, 127.3, 255.7, 383.7, 512.3, 644.2, 775.3, 904.7]

# %%
m.append(m[0] - 494.3)
print(m[1])
d.append([0,101.1 , 203.1 , 303.5 , 400.0 , 493.6])
OX = np.arange(0,6,1)
plt.grid(True)
plt.plot(OX,d[1] , "-ob")
print(d[1])
# Out:
# 548.0
# [0, 101.1, 203.1, 303.5, 400.0, 493.6]

# %%
m.append(m[0] + 501.8)
print(m[2])

OX = np.arange(0,5,1)
d.append([0 , 166.0 , 331.9 , 498.0 , 668.1])
print(d[2])
plt.plot(OX,d[2] , "-ob")
plt.show()
# Out:
# 1544.1
# [0, 166.0, 331.9, 498.0, 668.1]

# %%
m.append(m[2] + 464.9)
print(m[3])

OX = np.arange(0,5)
d.append([0 , 170.5 , 341.4 , 516.9 , 687.0])
print(d[3])
plt.plot(OX , d[3] , "-ob")
plt.show()
# Out:
# 2009.0
# [0, 170.5, 341.4, 516.9, 687.0]

# %%
m.append(m[3] + 505.5)
print(m[4])
OX = np.arange(0,5)
d.append([0 , 208.7, 418.3 , 629.0 , 837.1])
print(d[4])
plt.plot(OX , d[4] , "-ob")
plt.show()
# Out:
# 2514.5

# %%
L = 50 * 1e-2

tg = [(d[i][2] - d[i][1]) for i in range(5)]
u = [tg[i] * 2 * L for i in range(5)]
u2 = [ui**2 for ui in u]
# k = m[1]
# m[1] = m[0]
# m[0] = k

k = u2[1]
u2[1] = u2[0]
u2[0] = k
F = [m[i] * 1e-3 * 9.81 for i in range(len(m))]
print(m)
print(F)
print(u2)

plt.plot(F , u2)
plt.show()
# Out:
# [548.0, 1042.3, 1544.1, 2009.0, 2514.5]
# [5.37588, 10.224963, 15.147621000000001, 19.70829, 24.667245]
# [10404.0, 16486.559999999994, 27522.809999999994, 29206.80999999999, 43932.16000000001]
