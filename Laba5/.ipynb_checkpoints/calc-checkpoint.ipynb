# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
% matplotlib inline
OX = np.arange(0,8,1)
m = np.array([498.0 , 494.3 , 50.0])
m1 = m.sum()
d1 = [0 ,127.3 ,255.7, 383.7 , 512.3 , 644.2, 775.3, 904.7]
print(m1)
print(d1)
plt.plot(OX,d1 , "-ob")
plt.show()
# Out:
# 1042.3
# [0, 127.3, 255.7, 383.7, 512.3, 644.2, 775.3, 904.7]

# %%
m2 = m1 - 494.3
print(m2)
d2 = [0,101.1 , 203.1 , 303.5 , 400.0 , 493.6]
OX = np.arange(0,6,1)
plt.plot(OX,d2 , "-ob")
print(d2)
# Out:
# 548.0
# [0, 101.1, 203.1, 303.5, 400.0, 493.6]

# %%
m3 = m1 + 501.8
print(m3)

OX = np.arange(0,5,1)
d3 = [0 , 166.0 , 331.9 , 498.0 , 668.1]
print(d3)
plt.plot(OX,d3 , "-ob")
plt.show()
# Out:
# 1544.1
# [0, 166.0, 331.9, 498.0, 668.1]

# %%
m4 = m3 + 464.9
print(m4)

OX = np.arange(0,5)
d4 = [0 , 170.5 , 341.4 , 516.9 , 687.0]
print(d4)
plt.plot(OX , d4 , "-ob")
plt.show()
# Out:
# 2009.0
# [0, 170.5, 341.4, 516.9, 687.0]
# [170.5, 341.0, 511.5, 682.0]

# %%
m5 = m4 + 505.5
print(m5)

OX = np.arange(0,5)
d5 = [0 , 208.7]
exp = [d4[1] * k for k in range(1,5)]
print(exp)
# Out:
# 2514.5
# [170.5, 341.0, 511.5, 682.0]
